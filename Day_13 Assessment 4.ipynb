# %%
from ultralytics import YOLO
model = YOLO()
model.train(data = 'data.yaml', epochs = 20 ,batch = 2)
# Out:
# New https://pypi.org/project/ultralytics/8.0.141 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.136  Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model1 = YOLO('D:/CLG/PYTHON/Aircraft.v3i.yolov8/runs/detect/train9/weights/best.pt')

# %%
results = model1('peakpx.jpg',save = True,save_txt = True)
# Out:
# image 1/1 D:\CLG\PYTHON\Aircraft.v3i.yolov8\peakpx.jpg: 320x640 2 Aircrafts, 132.1ms
# Speed: 3.0ms preprocess, 132.1ms inference, 11.1ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to C:\Users\subra\runs\detect\predict3
# 1 label saved to C:\Users\subra\runs\detect\predict3\labels

# %%
model1.predict('C:/Users/subra/OneDrive/Desktop/b1.mp4',save = True,save_txt = True)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/325) C:\Users\subra\OneDrive\Desktop\b1.mp4: 384x640 9 Aircrafts, 244.6ms
# video 1/1 (2/325) C:\Users\subra\OneDrive\Desktop\b1.mp4: 384x640 10 Aircrafts, 170.6ms
# video 1/1 (3/325) C:\Users\subra\OneDrive\Desktop\b1.mp4: 384x640 12 Aircrafts, 137.1ms
# video 1/1 (4/325) C:\Users\subra\OneDrive\Desktop\b1.mp4: 384x640 12 Aircrafts, 175.6ms
# ...
