# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('Sri Lanka/sri.csv')
data
# Out:
#                                                    Title  \
# 0            House with Land for Sale in Matara for sale
# 1      à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
# 2         Kelaniya - House on 20P Land for sale for sale
# 3      House For Sale in Pamankada Lane Wellawatte Co...
# 4                     House For Sale - Attidiya for sale
# ...                                                  ...
# 15322                  House for sale Nittabuwa for sale
# 15323               House for Sale - Wellawatte for sale
# 15324   House with 20 Perches Land - Maharagama for sale
# 15325              House for sale in Maharagama for sale
# 15326              Mount Lavinia House for Sale for sale
#
#                                              Sub_title           Price  \
# 0        Posted on 06 Nov 2:32 pm, Matara City, Matara    Rs 5,400,000
# 1      Posted on 24 Oct 7:27 am, Athurugiriya, Colombo   Rs 16,800,000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15327 entries, 0 to 15326
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           15327 non-null  object
#  1   Sub_title       15327 non-null  object
#  2   Price           15327 non-null  object
#  3   Address         11191 non-null  object
#  4   Baths           15327 non-null  object
#  5   Land size       15327 non-null  object
#  6   Beds            15327 non-null  object
#  7   House size      15327 non-null  object
#  8   Location        15327 non-null  object
#  9   Description     15327 non-null  object
#  10  Post_URL        15327 non-null  object
#  11  Seller_name     15327 non-null  object
#  12  Seller_type     15327 non-null  object
#  13  published_date  15327 non-null  object
#  14  Geo_Address     15327 non-null  object
#  15  Lat             15327 non-null  float64
#  16  Lon             15327 non-null  float64
# ...

# %%
data = data.drop(['Address'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15327 entries, 0 to 15326
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           15327 non-null  object
#  1   Sub_title       15327 non-null  object
#  2   Price           15327 non-null  object
#  3   Baths           15327 non-null  object
#  4   Land size       15327 non-null  object
#  5   Beds            15327 non-null  object
#  6   House size      15327 non-null  object
#  7   Location        15327 non-null  object
#  8   Description     15327 non-null  object
#  9   Post_URL        15327 non-null  object
#  10  Seller_name     15327 non-null  object
#  11  Seller_type     15327 non-null  object
#  12  published_date  15327 non-null  object
#  13  Geo_Address     15327 non-null  object
#  14  Lat             15327 non-null  float64
#  15  Lon             15327 non-null  float64
# dtypes: float64(2), object(14)
# memory usage: 1.9+ MB

# %%
data
# Out:
#                                                    Title  \
# 0            House with Land for Sale in Matara for sale
# 1      à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
# 2         Kelaniya - House on 20P Land for sale for sale
# 3      House For Sale in Pamankada Lane Wellawatte Co...
# 4                     House For Sale - Attidiya for sale
# ...                                                  ...
# 15322                  House for sale Nittabuwa for sale
# 15323               House for Sale - Wellawatte for sale
# 15324   House with 20 Perches Land - Maharagama for sale
# 15325              House for sale in Maharagama for sale
# 15326              Mount Lavinia House for Sale for sale
#
#                                              Sub_title           Price Baths  \
# 0        Posted on 06 Nov 2:32 pm, Matara City, Matara    Rs 5,400,000     1
# 1      Posted on 24 Oct 7:27 am, Athurugiriya, Colombo   Rs 16,800,000     3
# ...

# %%
data['Price'] = data['Price'].str.replace('Rs ','')
data.head()
# Out:
#                                                Title  \
# 0        House with Land for Sale in Matara for sale
# 1  à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
# 2     Kelaniya - House on 20P Land for sale for sale
# 3  House For Sale in Pamankada Lane Wellawatte Co...
# 4                 House For Sale - Attidiya for sale
#
#                                          Sub_title        Price  \
# 0    Posted on 06 Nov 2:32 pm, Matara City, Matara    5,400,000
# 1  Posted on 24 Oct 7:27 am, Athurugiriya, Colombo   16,800,000
# 2      Posted on 17 Nov 5:19 pm, Kelaniya, Gampaha   20,000,000
# 3     Posted on 17 Nov 5:07 pm, Colombo 6, Colombo  187,000,000
# 4      Posted on 17 Nov 5:06 pm, Dehiwala, Colombo    1,300,000
#
#                                 Address Baths     Land size Beds  \
# 0     Gangodagama Roard,Hakmana,Matara.     1  50.0 perches    3
# 1            Athurugiriya Galwarusapare     3   8.0 perches    3
# ...

# %%
data['Price'] = data['Price'].str.replace(',','')

# %%
data['Price'] = data['Price'].astype(int)

# %%
filtered_data = data[data['Price']>500000]
filtered_data
# Out:
#                                                    Title  \
# 0            House with Land for Sale in Matara for sale
# 1      à¶
# à¶½à·à¶­à· à¶à·à¶¸à¶» 3 à¶ à¶à·à· à...
# 2         Kelaniya - House on 20P Land for sale for sale
# 3      House For Sale in Pamankada Lane Wellawatte Co...
# 4                     House For Sale - Attidiya for sale
# ...                                                  ...
# 15322                  House for sale Nittabuwa for sale
# 15323               House for Sale - Wellawatte for sale
# 15324   House with 20 Perches Land - Maharagama for sale
# 15325              House for sale in Maharagama for sale
# 15326              Mount Lavinia House for Sale for sale
#
#                                              Sub_title      Price  \
# 0        Posted on 06 Nov 2:32 pm, Matara City, Matara    5400000
# 1      Posted on 24 Oct 7:27 am, Athurugiriya, Colombo   16800000
# 2          Posted on 17 Nov 5:19 pm, Kelaniya, Gampaha   20000000
# ...

# %%
sns.countplot(data = data,x = 'Beds')
# Out:
# <AxesSubplot:xlabel='Beds', ylabel='count'>

# %%
sns.countplot(data = data,x = 'Seller_type')
# Out:
# <AxesSubplot:xlabel='Seller_type', ylabel='count'>
